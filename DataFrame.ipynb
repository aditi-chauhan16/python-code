# %% [markdown]
# <a href="https://colab.research.google.com/github/aditi-chauhan16/python-code/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
l1=["40004007","shanvi","kumari","python","shanvi",81]
l2=["40004006","aditi","chauhan","python","aditi",85]
l3=["40004005","shubhi","chauhan","python","shubhi",80]
df=pd.DataFrame(data=np.array([l1,l2,l3]))
print(df)
a2=np.array([l1,l2,l3])
print(a2)

a2[2]="AK"
print(a2)
# Out:
#           0       1        2       3       4   5
# 0  40004007  shanvi   kumari  python  shanvi  81
# 1  40004006   aditi  chauhan  python   aditi  85
# 2  40004005  shubhi  chauhan  python  shubhi  80
# [['40004007' 'shanvi' 'kumari' 'python' 'shanvi' '81']
#  ['40004006' 'aditi' 'chauhan' 'python' 'aditi' '85']
#  ['40004005' 'shubhi' 'chauhan' 'python' 'shubhi' '80']]
# [['40004007' 'shanvi' 'kumari' 'python' 'shanvi' '81']
#  ['40004006' 'aditi' 'chauhan' 'python' 'aditi' '85']
#  ['AK' 'AK' 'AK' 'AK' 'AK' 'AK']]

# %%
# !pip install pandas
# !pip install numpy
import numpy as np
import pandas as pd
import seaborn as sns
l1=["500127057","Vaibhav","kukur","python","84"]
l2=["500127057","Vidit","Panwar","python","56"]
l3=["500127057","Srishti","batham","python","99"]
l4=["500127057","Ishumasi","Bidholi","python","80"]
df=pd.DataFrame(data=np.array([l1,l2,l3,l4]),index = ["student1", "student2", "student3", "student4"]
                                                  ,columns = ["SapID", "Fname", "Lname", "subject", "marks"])
print(df)
df["marks"] = pd.to_numeric(df["marks"])
sns.pairplot(df)
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
#               SapID     Fname    Lname subject marks
# student1  500127057   Vaibhav    kukur  python    84
# student2  500127057     Vidit   Panwar  python    56
# student3  500127057   Srishti   batham  python    99
# student4  500127057  Ishumasi  Bidholi  python    80

# %%
df.head()
# Out:
#               SapID     Fname    Lname subject  marks
# student1  500127057   Vaibhav    kukur  python     84
# student2  500127057     Vidit   Panwar  python     56
# student3  500127057   Srishti   batham  python     99
# student4  500127057  Ishumasi  Bidholi  python     80

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   79.750000
# std    17.820868
# min    56.000000
# 25%    74.000000
# 50%    82.000000
# 75%    87.750000
# max    99.000000

# %%
df.tail()
# Out:
#               SapID     Fname    Lname subject  marks
# student1  500127057   Vaibhav    kukur  python     84
# student2  500127057     Vidit   Panwar  python     56
# student3  500127057   Srishti   batham  python     99
# student4  500127057  Ishumasi  Bidholi  python     80
